# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math
from scipy import interpolate

# %%
p=np.array([1.6,1.6,1.6,1.7,1.7,1.7,1.7,1.7,1.8,1.8,1.8,1.8]) # pressure in mm Water
v=np.array([5,5,5,5.1,5.1,5.1,5.2,5.2,5.2,5.2,5.2,5.2]) # velocity in m/s
x=np.array([0.10463,0.15493,0.20523,0.40141,0.45171,0.50201,0.65292,0.70322,0.75352
            ,0.80382,0.85412,0.90443]) #position of ports
Po=np.add()
P_inf = 1.5*9.80665
# Calculating Cp
p=p*9.80665 # convert to Pa
cp=np.divide(p,v)
cp=np.divide(cp,v)
cp=2/1.225*cp

print('Coefficient of Pressures are: ',cp)

fig=plt.figure(figsize=(10,7))
l1,=plt.plot(x,p)
l2,=plt.plot(x,v)
l3,=plt.plot(x,cp)
plt.xlabel('x/L')
plt.legend((l1,l2,l3),('Pressure (in Pa)','Velocity (in m/s)','Coefficient of Pressure'))
fig.savefig("prelocity.png", bbox_inches='tight', dpi=300)
# Out:
# Coefficient of Pressures are:  [1.00067857 1.00067857 1.00067857 1.0477063  1.0477063  0.99840946
#  1.08917396 1.07510921 1.03910376 1.03910376 0.95251178 1.03910376]
