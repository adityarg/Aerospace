# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import xlrd
# %matplotlib inline

# %%
d={'-2': [27.3,27.5,28.2,29.6,31], '-1.6': [28.7,30,35,56,71], '-1.2': [115,231,271,331,301],
   '-0.8': [795,861,935,761,774], '-0.4': [1092,1097,1117,1063,1016], '0': [778,815,1131,1088,1044],
   '0.4': [978,1097,1117,1063,1016], '0.8': [790,861,935,761,774], '1.2': [100,231,271,331,301],
   '1.6': [30,30,35,56,71], '2': [26.3,27.5,28.2,29.6,32]}

# %%
df=pd.DataFrame(data=d)

# %%
fig, ax = plt.subplots(figsize=(9, 14))
svm=sns.heatmap(ax=ax, data=df)

# %%
figure = svm.get_figure()    
figure.savefig('svm_conf.png', dpi=800)
